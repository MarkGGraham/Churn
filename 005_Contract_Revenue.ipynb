# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine
import warnings
import time
from matplotlib import rcParams
sns.set_theme(style="darkgrid")
warnings.simplefilter(action="ignore", category=FutureWarning)
engine = create_engine('postgresql://root:root@localhost:5432/churn')

# %%
# %time df = pd.read_sql("select * from v_churn", con=engine)
# Out:
# Wall time: 184 ms

# %%
df.head(2)
# Out:
#   churned  tenure  contract  monthly_charge  total_charge
# 0      No      68  Two year            84.7       5711.05
# 1      No      12  Two year            25.4        313.00

# %%
sns.histplot(data=df, x="monthly_charge", hue="contract", multiple="stack" )
sns.displot(data=df, x="monthly_charge", hue="contract", multiple="stack" , kind="kde")

# sns.histplot(data=df, x="total_charge", hue="contract", multiple="stack" )
# sns.displot(data=df, x="total_charge", hue="contract", multiple="stack" , kind="kde")
# Out:
# Wall time: 36 ms
