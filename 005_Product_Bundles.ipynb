# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine
import warnings
import time
from matplotlib import rcParams
sns.set_theme(style="darkgrid")
warnings.simplefilter(action="ignore", category=FutureWarning)
engine = create_engine('postgresql://root:root@localhost:5432/churn')
sns.set_context("talk")

# %%
# %time df = pd.read_sql("select * from v_single_sub LIMIT 10", con=engine)
# Out:
# Wall time: 18.2 ms

# %%
plt.title("Top 10 Products", size=30)
plt.rcParams['figure.figsize']=10, 7
x = sns.barplot(data=df, x="product", y="product_count")
x.set_ylabel("Number of Customers")
x.set_xlabel("Product")
x.tick_params(axis='x', rotation=60)

# %%
# %time df = pd.read_sql("select * from v_double_sub LIMIT 10", con=engine)
# Out:
# Wall time: 413 ms

# %%
df.head(2)
# Out:
#                     product_bundle product_code_bundle  product_count
# 0  Streaming-Movies - Streaming-TV        STRM - STRTV           1940
# 1     Internet-Fiber - Phone-Multi          IFIB - PHM           1938

# %%
plt.title("Top 10 Product Bundles (2 Products)", size=30)
# plt.rcParams['figure.figsize']=10, 7
x = sns.barplot(data=df, x="product_bundle", y="product_count")
x.tick_params(axis='x', rotation=90)
x.set_ylabel("Number of Customers")
x.set_xlabel("Product Bundle")
x.tick_params(axis='x', rotation=60)
